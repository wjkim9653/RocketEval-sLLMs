# %% [markdown]
# <h1 align="center">🚀 RocketEval 🚀</h1>
# <h3 align="center">Efficiently Evaluate LLMs using Google Colab</h3>
#
# This notebook will run a full evaluation process of [RocketEval](https://github.com/Joinn99/RocketEval-ICLR) using a single Tesla T4 GPU in Google Colab.
#
# RocketEval is an efficient automated evaluation framework for Large Language Models (LLMs) that uses a checklist-based grading approach. This notebook demonstrates how to:
#
# 1. Set up the evaluation environment on Google Colab
# 2. Run evaluations using a lightweight model (*Qwen2.5-0.5B-Instruct*) as the judge
# 3. Evaluate multiple LLM responses on the *MT-Bench* dataset
# 4. Generate evaluation scores and rankings efficiently with limited compute resources
#
# The entire process is optimized to run on a single Tesla T4 GPU, making it accessible for users with basic GPU resources.

# %% [markdown]
# ------
#
# First, clone our github repo. This repository contains the implementation of RocketEval, an efficient automated evaluation framework for Large Language Models (LLMs) that uses a checklist-based grading approach. The repository includes:
#
# - Evaluation scripts and utilities
# - Example benchmark datasets (MT-Bench, AlpacaEval, etc.)
# - Model configurations for both API and local deployment
# - Documentation and examples

# %%
# Clone the repo
# !git clone https://github.com/Joinn99/RocketEval-ICLR.git
# Download the data
# !git clone https://huggingface.co/datasets/Joinn/RocketEval && mv RocketEval RocketEval-ICLR/data
# Out:
# Cloning into 'RocketEval-ICLR'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 43 (delta 4), reused 43 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (43/43), 40.25 KiB | 6.71 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# Cloning into 'RocketEval'...
# remote: Enumerating objects: 607, done.
# remote: Counting objects: 100% (604/604), done.
# remote: Compressing objects: 100% (597/597), done.
# remote: Total 607 (delta 92), reused 0 (delta 0), pack-reused 3 (from 1)
# Receiving objects: 100% (607/607), 296.68 MiB | 5.94 MiB/s, done.
# Resolving deltas: 100% (92/92), done.
# Updating files: 100% (573/573), done.

# %% [markdown]
# ------
#
# Go to the target dir, and install the necessary dependencies.
#
# We need to:
# 1. Change to the RocketEval directory
# 2. Install the required packages from requirements.txt
#
# The requirements.txt file contains all the necessary Python packages including:
# - `vllm` for local model deployment
# - `openai` for API access
# - `scikit-learn` for evaluation metrics
# - Other utility packages

# %%
# %cd RocketEval-ICLR
# !pip install -r requirements.txt
# Out:
# /content/RocketEval-ICLR
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (1.61.1)
# Collecting datasets (from -r requirements.txt (line 2))
#   Downloading datasets-3.3.1-py3-none-any.whl.metadata (19 kB)
# Collecting vllm>=0.7.2 (from -r requirements.txt (line 3))
#   Downloading vllm-0.7.2-cp38-abi3-manylinux1_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (1.6.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (13.9.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (0.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai->-r requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai->-r requirements.txt (line 1)) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai->-r requirements.txt (line 1)) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai->-r requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets->-r requirements.txt (line 2)) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets->-r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets->-r requirements.txt (line 2)) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->-r requirements.txt (line 2))
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets->-r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets->-r requirements.txt (line 2)) (2.32.3)
# Collecting xxhash (from datasets->-r requirements.txt (line 2))
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets->-r requirements.txt (line 2))
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets->-r requirements.txt (line 2)) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets->-r requirements.txt (line 2)) (3.11.12)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets->-r requirements.txt (line 2)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from vllm>=0.7.2->-r requirements.txt (line 3)) (5.9.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from vllm>=0.7.2->-r requirements.txt (line 3)) (0.2.0)
# Collecting blake3 (from vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading blake3-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from vllm>=0.7.2->-r requirements.txt (line 3)) (9.0.0)
# Requirement already satisfied: transformers>=4.48.2 in /usr/local/lib/python3.11/dist-packages (from vllm>=0.7.2->-r requirements.txt (line 3)) (4.48.3)
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.11/dist-packages (from vllm>=0.7.2->-r requirements.txt (line 3)) (0.21.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from vllm>=0.7.2->-r requirements.txt (line 3)) (4.25.6)
# Collecting fastapi!=0.113.*,!=0.114.0,>=0.107.0 (from vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading fastapi-0.115.8-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn[standard] (from vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: prometheus_client>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from vllm>=0.7.2->-r requirements.txt (line 3)) (0.21.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from vllm>=0.7.2->-r requirements.txt (line 3)) (11.1.0)
# Collecting prometheus-fastapi-instrumentator>=7.0.0 (from vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading prometheus_fastapi_instrumentator-7.0.2-py3-none-any.whl.metadata (13 kB)
# Collecting tiktoken>=0.6.0 (from vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting lm-format-enforcer<0.11,>=0.10.9 (from vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading lm_format_enforcer-0.10.10-py3-none-any.whl.metadata (17 kB)
# Collecting outlines==0.1.11 (from vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading outlines-0.1.11-py3-none-any.whl.metadata (17 kB)
# Collecting lark==1.2.2 (from vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting xgrammar>=0.1.6 (from vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading xgrammar-0.1.13-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (2.9 kB)
# Collecting partial-json-parser (from vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading partial_json_parser-0.2.1.1.post5-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.11/dist-packages (from vllm>=0.7.2->-r requirements.txt (line 3)) (24.0.1)
# Collecting msgspec (from vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting gguf==0.10.0 (from vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading gguf-0.10.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/dist-packages (from vllm>=0.7.2->-r requirements.txt (line 3)) (8.6.1)
# Collecting mistral_common>=1.5.0 (from mistral_common[opencv]>=1.5.0->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading mistral_common-1.5.3-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from vllm>=0.7.2->-r requirements.txt (line 3)) (0.8.1)
# Collecting compressed-tensors==0.9.1 (from vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading compressed_tensors-0.9.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting depyf==0.18.0 (from vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading depyf-0.18.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from vllm>=0.7.2->-r requirements.txt (line 3)) (3.1.1)
# Collecting ray>=2.9 (from ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading ray-2.42.1-cp311-cp311-manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting nvidia-ml-py>=12.560.30 (from vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading nvidia_ml_py-12.570.86-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.11/dist-packages (from vllm>=0.7.2->-r requirements.txt (line 3)) (2.5.1+cu124)
# Requirement already satisfied: torchaudio==2.5.1 in /usr/local/lib/python3.11/dist-packages (from vllm>=0.7.2->-r requirements.txt (line 3)) (2.5.1+cu124)
# Requirement already satisfied: torchvision==0.20.1 in /usr/local/lib/python3.11/dist-packages (from vllm>=0.7.2->-r requirements.txt (line 3)) (0.20.1+cu124)
# Collecting xformers==0.0.28.post3 (from vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading xformers-0.0.28.post3-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting astor (from depyf==0.18.0->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting interegular (from outlines==0.1.11->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading interegular-0.3.3-py37-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm>=0.7.2->-r requirements.txt (line 3)) (3.1.5)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm>=0.7.2->-r requirements.txt (line 3)) (1.6.0)
# Collecting diskcache (from outlines==0.1.11->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: referencing in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm>=0.7.2->-r requirements.txt (line 3)) (0.36.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm>=0.7.2->-r requirements.txt (line 3)) (4.23.0)
# Collecting pycountry (from outlines==0.1.11->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting airportsdata (from outlines==0.1.11->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading airportsdata-20241001-py3-none-any.whl.metadata (8.9 kB)
# Collecting outlines_core==0.1.26 (from outlines==0.1.11->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading outlines_core-0.1.26-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm>=0.7.2->-r requirements.txt (line 3)) (3.4.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.5.1->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.5.1->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.5.1->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.5.1->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.5.1->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.5.1->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.5.1->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.5.1->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.5.1->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm>=0.7.2->-r requirements.txt (line 3)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm>=0.7.2->-r requirements.txt (line 3)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.5.1->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm>=0.7.2->-r requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm>=0.7.2->-r requirements.txt (line 3)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.5.1->vllm>=0.7.2->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->-r requirements.txt (line 5)) (2.18.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 1)) (3.10)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi!=0.113.*,!=0.114.0,>=0.107.0->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (1.18.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 1)) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: opencv-python-headless>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mistral_common[opencv]>=1.5.0->vllm>=0.7.2->-r requirements.txt (line 3)) (4.11.0.86)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 1)) (2.27.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3)) (8.1.8)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3)) (1.1.0)
# Collecting aiohttp-cors (from ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl.metadata (20 kB)
# Collecting colorful (from ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading colorful-0.5.6-py2.py3-none-any.whl.metadata (16 kB)
# Collecting opencensus (from ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.11/dist-packages (from ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3)) (7.1.0)
# Collecting virtualenv!=20.21.1,>=20.0.24 (from ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading virtualenv-20.29.2-py3-none-any.whl.metadata (4.5 kB)
# Collecting py-spy>=0.2.0 (from ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.11/dist-packages (from ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3)) (1.70.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.6.0->vllm>=0.7.2->-r requirements.txt (line 3)) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.2->vllm>=0.7.2->-r requirements.txt (line 3)) (0.5.2)
# Collecting pybind11 (from xgrammar>=0.1.6->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.11/dist-packages (from xgrammar>=0.1.6->vllm>=0.7.2->-r requirements.txt (line 3)) (8.3.4)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata->vllm>=0.7.2->-r requirements.txt (line 3)) (3.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->-r requirements.txt (line 2)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->-r requirements.txt (line 2)) (2025.1)
# Collecting httptools>=0.6.3 (from uvicorn[standard]->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]->vllm>=0.7.2->-r requirements.txt (line 3)) (14.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->outlines==0.1.11->vllm>=0.7.2->-r requirements.txt (line 3)) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->outlines==0.1.11->vllm>=0.7.2->-r requirements.txt (line 3)) (0.22.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->-r requirements.txt (line 2)) (1.17.0)
# Collecting distlib<1,>=0.3.7 (from virtualenv!=20.21.1,>=20.0.24->ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3)) (4.3.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->outlines==0.1.11->vllm>=0.7.2->-r requirements.txt (line 3)) (3.0.2)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3))
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from opencensus->ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3)) (2.19.2)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest->xgrammar>=0.1.6->vllm>=0.7.2->-r requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest->xgrammar>=0.1.6->vllm>=0.7.2->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open->ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3)) (1.17.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3)) (1.67.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3)) (1.26.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3)) (2.27.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3)) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3)) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3)) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm>=0.7.2->-r requirements.txt (line 3)) (0.6.1)
# Downloading datasets-3.3.1-py3-none-any.whl (484 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 23.3 MB/s eta 0:00:00
# Downloading vllm-0.7.2-cp38-abi3-manylinux1_x86_64.whl (264.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.3/264.3 MB 5.2 MB/s eta 0:00:00
# Downloading compressed_tensors-0.9.1-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 9.5 MB/s eta 0:00:00
# Downloading depyf-0.18.0-py3-none-any.whl (38 kB)
# Downloading gguf-0.10.0-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 6.9 MB/s eta 0:00:00
# Downloading lark-1.2.2-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 11.2 MB/s eta 0:00:00
# Downloading outlines-0.1.11-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 8.7 MB/s eta 0:00:00
# Downloading xformers-0.0.28.post3-cp311-cp311-manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 91.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 66.0 MB/s eta 0:00:00
# Downloading outlines_core-0.1.26-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (343 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.3/343.3 kB 25.7 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.7 MB/s eta 0:00:00
# Downloading fastapi-0.115.8-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 9.6 MB/s eta 0:00:00
# Downloading lm_format_enforcer-0.10.10-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 3.8 MB/s eta 0:00:00
# Downloading mistral_common-1.5.3-py3-none-any.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 80.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.0 MB/s eta 0:00:00
# Downloading nvidia_ml_py-12.570.86-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.9 MB/s eta 0:00:00
# Downloading prometheus_fastapi_instrumentator-7.0.2-py3-none-any.whl (18 kB)
# Downloading ray-2.42.1-cp311-cp311-manylinux2014_x86_64.whl (67.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.4/67.4 MB 10.3 MB/s eta 0:00:00
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 62.4 MB/s eta 0:00:00
# Downloading xgrammar-0.1.13-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (402 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.4/402.4 kB 32.4 MB/s eta 0:00:00
# Downloading blake3-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (376 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.2/376.2 kB 30.0 MB/s eta 0:00:00
# Downloading msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.7/210.7 kB 17.9 MB/s eta 0:00:00
# Downloading partial_json_parser-0.2.1.1.post5-py3-none-any.whl (10 kB)
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 17.6 MB/s eta 0:00:00
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 35.1 MB/s eta 0:00:00
# Downloading interegular-0.3.3-py37-none-any.whl (23 kB)
# Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 95.1 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 7.0 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 101.5 MB/s eta 0:00:00
# Downloading virtualenv-20.29.2-py3-none-any.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 108.3 MB/s eta 0:00:00
# Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.6/452.6 kB 35.7 MB/s eta 0:00:00
# Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Downloading airportsdata-20241001-py3-none-any.whl (912 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 912.7/912.7 kB 53.6 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading colorful-0.5.6-py2.py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 15.9 MB/s eta 0:00:00
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.5 MB/s eta 0:00:00
# Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 12.6 MB/s eta 0:00:00
# Downloading pybind11-2.13.6-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 kB 20.9 MB/s eta 0:00:00
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 108.9 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.1 MB/s eta 0:00:00
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 32.2 MB/s eta 0:00:00
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Installing collected packages: py-spy, opencensus-context, nvidia-ml-py, distlib, colorful, blake3, xxhash, virtualenv, uvloop, uvicorn, python-dotenv, pycountry, pybind11, partial-json-parser, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, msgspec, lark, interegular, httptools, gguf, diskcache, dill, astor, airportsdata, watchfiles, tiktoken, starlette, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, depyf, prometheus-fastapi-instrumentator, nvidia-cusolver-cu12, lm-format-enforcer, fastapi, aiohttp-cors, ray, outlines_core, opencensus, mistral_common, datasets, xgrammar, xformers, outlines, compressed-tensors, vllm
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed aiohttp-cors-0.7.0 airportsdata-20241001 astor-0.8.1 blake3-1.0.4 colorful-0.5.6 compressed-tensors-0.9.1 datasets-3.3.1 depyf-0.18.0 dill-0.3.8 diskcache-5.6.3 distlib-0.3.9 fastapi-0.115.8 gguf-0.10.0 httptools-0.6.4 interegular-0.3.3 lark-1.2.2 lm-format-enforcer-0.10.10 mistral_common-1.5.3 msgspec-0.19.0 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-ml-py-12.570.86 nvidia-nvjitlink-cu12-12.4.127 opencensus-0.11.4 opencensus-context-0.1.3 outlines-0.1.11 outlines_core-0.1.26 partial-json-parser-0.2.1.1.post5 prometheus-fastapi-instrumentator-7.0.2 py-spy-0.4.0 pybind11-2.13.6 pycountry-24.6.1 python-dotenv-1.0.1 ray-2.42.1 starlette-0.45.3 tiktoken-0.9.0 uvicorn-0.34.0 uvloop-0.21.0 virtualenv-20.29.2 vllm-0.7.2 watchfiles-1.0.4 xformers-0.0.28.post3 xgrammar-0.1.13 xxhash-3.5.0

# %% [markdown]
# ------
#
# Next, we'll configure the evaluation parameters. This notebook demonstrates a minimal evaluation setup with the following key arguments:
#
# - `dataset`: [MT-Bench](https://huggingface.co/spaces/lmsys/mt-bench/tree/main), a compact LLM evaluation dataset
# - `generator`: [GPT-4](https://chatgpt.com/) for checklist generation (we'll use pre-generated checklists)
# - `judge`: [Qwen2.5-0.5B-Instruct](https://huggingface.co/Qwen/Qwen2.5-0.5B-Instruct), chosen for efficient evaluation on a Tesla T4 GPU
# - `train_test`: Enables split evaluation using model sets from:
#   - Training: `config/rankings/mt-bench_train.json`
#   - Testing: `config/rankings/mt-bench_test.json`
# - `mode`: "offline" to utilize the local vLLM framework
# - `gpu_ids`: "0" for single GPU execution
# - `offline_config`: vLLM engine configuration file path

# %%
# Arguments for the evaluation task
default_args="""--dataset mt-bench --generator gpt-4o --judge Qwen2.5-0.5B-Instruct --train_test --mode offline --gpu_ids 0 --offline_config config/offline/colab.yaml""".split()

# %% [markdown]
# ------
#
# Next, we start to run our task.
#
# We'll use the default arguments defined above to:
# 1. Load the MT-Bench dataset
# 2. Initialize the Qwen2.5-0.5B-Instruct judge model using vLLM
# 3. Run the evaluation pipeline including:
#    - Checklist-based grading
#    - Score aggregation
#    - Model ranking

# %%
#@title Running Evaluation Task

import sys
import os

rocketeval_dir = os.path.join(os.path.abspath(os.curdir), "src")
sys.path.insert(0, rocketeval_dir)

import time
import openai
import logging
import argparse

from rich.logging import RichHandler
from rich.console import Console
from rich.markdown import Markdown

from rocketeval.data.data_loader import load_target_models
from rocketeval.task import checklist_task, judgment_task, ranking_task, score_task

logging.getLogger('RootLogger').setLevel(logging.INFO)

logging.basicConfig(
    level=logging.INFO,
    format="%(message)s",
    datefmt="[%X]",
    handlers=[RichHandler()],
    force=True
)

parser = argparse.ArgumentParser(description="RocketEval Task Runner")

# Data
parser.add_argument("--data_dir", default="data/", help="Data directory")
parser.add_argument("--config_dir", default="config/", help="Config directory")

# Model
parser.add_argument("--dataset", default="mt-bench", help="Dataset name")
parser.add_argument("--generator", default="gpt-4o", help="Generator model")
parser.add_argument("--judge", default="gpt-4o", help="Judge model")
parser.add_argument("--labeler", default="gpt-4o", help="Labeler judge that provides labels")
parser.add_argument("--train_test", action="store_true", help="Use specific train-test split")
parser.add_argument("--gen_checklist", action="store_true", help="Generate checklist")

# Running Mode
parser.add_argument("--mode", choices=["api", "offline"], help="Running mode, set to 'api' to use OpenAI API, set to 'offline' to use local models through vLLM")
parser.add_argument("--instant_api", action="store_true", help="Run using instant API.")
parser.add_argument("--api_parallel_size", default=1, help="Number of parallel API calls, adjust based on your API rate limit.")
parser.add_argument("--offline_config", default="config/offline/default.yaml", help="Path to vLLM config file")

# Others
parser.add_argument("--resume_from_task_id", default=None, help="Task ID")
parser.add_argument("--keep_batch_files", action="store_true", help="Keep batch files")
parser.add_argument("--gpu_ids", default="0", help="GPU IDs, split by comma")

args = parser.parse_args(default_args)
kwargs = vars(args)

task_id = f"{args.dataset}_{int(time.time())}" \
    if args.resume_from_task_id is None \
    else args.resume_from_task_id

if args.mode == "api":
    client = openai.OpenAI()
else:
    client = None
    if not os.path.exists(os.path.join(args.data_dir, "batch")):
      os.makedirs(os.path.join(args.data_dir, "batch"))

task_id = f"{args.dataset}_{args.judge}_{int(time.time())}" \
    if args.resume_from_task_id is None \
    else args.resume_from_task_id

train_model_names = load_target_models(
    data_dir=args.data_dir,
    config_dir=args.config_dir,
    dataset_name=args.dataset,
    split="train" if args.train_test else "full"
)

test_model_names = load_target_models(
    data_dir=args.data_dir,
    config_dir=args.config_dir,
    dataset_name=args.dataset,
    split="test" if args.train_test else "full"
)

logger = logging.getLogger("rich")

start_message = f"""[underline bold red on white blink]RocketEval[/]
[bold yellow on red blink] Task Information[/]
- Dataset: "{args.dataset}"
- Judge: "{args.judge}"
- Labeler: "{args.labeler}"
- Task ID: "{task_id}"
""".replace("\t", "")

logger.info(start_message, extra={"markup": True})


logger.info(f"[bold yellow on red blink]RocketEval Completed[/]", extra={"markup": True})

if args.gen_checklist:
    # I - Checklist Creation
    logger.info(
        "[bold yellow on red blink]I. Checklist Creation[/]", extra={"markup": True}
    )

    checklist_task(
        client=client,
        task_id=task_id,
        **kwargs
    )

    logger.info(
        f"[yellow]Checklist Creation completed.[/]\n\n",
        extra={"markup": True}
    )
else:
    logger.info(
        f"[bold yellow on red blink]Checklist Creation skipped.[/]", extra={"markup": True},
    )

# II - Judgment Creation
logger.info(
    "[bold yellow on red blink]II. Judgment Creation[/]", extra={"markup": True}
)

judgment_task(
    model_names=train_model_names + test_model_names,
    client=client,
    task_id=task_id,
    **kwargs
)

logger.info(
    f"[yellow]Judgment Creation completed.[/]\n\n",
    extra={"markup": True}
)


# III - Score Creation
logger.info(
    f"[bold yellow on red blink]III. Score Creation[/]",
    extra={"markup": True}
)

score_task(
    train_model_names=train_model_names,
    test_model_names=test_model_names,
    task_id=task_id,
    **kwargs
)

logger.info(
    f"[yellow]Score Creation completed.[/]\n\n",
    extra={"markup": True}
)


# IV - Ranking
logger.info(
    f"[bold yellow on red blink]IV. Ranking[/]",
    extra={"markup": True}
)

ranking = ranking_task(
    model_names=test_model_names,
    **kwargs
)

Console().print(Markdown(ranking.to_markdown()), justify="center")

logger.info(
    f"[yellow]Ranking completed.[/]\n\n",
    extra={"markup": True}
)


# Finish
logger.info(
    f"[bold yellow on red blink]RocketEval Completed[/]",
    extra={"markup": True}
)
# Out:
# INFO 02-19 06:24:54 __init__.py:190] Automatically detected platform cuda.
# [06:24:54] INFO     RocketEval                                                    ]8;id=540311;file://<ipython-input-4-049d212b5d3f>\<ipython-input-4-049d212b5d3f>]8;;\:]8;id=568636;file://<ipython-input-4-049d212b5d3f>#98\98]8;;\
#                      Task Information
#                     - Dataset: "mt-bench"
#                     - Judge: "Qwen2.5-0.5B-Instruct"
#                     - Labeler: "gpt-4o"
#                     - Task ID: "mt-bench_Qwen2.5-0.5B-Instruct_1739946294"
#            INFO     RocketEval Completed                                         ]8;id=949880;file://<ipython-input-4-049d212b5d3f>\<ipython-input-4-049d212b5d3f>]8;;\:]8;id=323584;file://<ipython-input-4-049d212b5d3f>#101\101]8;;\
#            INFO     Checklist Creation skipped.                                  ]8;id=927357;file://<ipython-input-4-049d212b5d3f>\<ipython-input-4-049d212b5d3f>]8;;\:]8;id=935047;file://<ipython-input-4-049d212b5d3f>#120\120]8;;\
#            INFO     II. Judgment Creation                                        ]8;id=876422;file://<ipython-input-4-049d212b5d3f>\<ipython-input-4-049d212b5d3f>]8;;\:]8;id=392514;file://<ipython-input-4-049d212b5d3f>#125\125]8;;\
#            INFO     Loaded 160 instances from 'mt-bench'                                             ]8;id=754896;file:///content/RocketEval-ICLR/src/rocketeval/process/judgment.py\judgment.py]8;;\:]8;id=685548;file:///content/RocketEval-ICLR/src/rocketeval/process/judgment.py#32\32]8;;\
#            INFO     Generated 1206 questions for judgment, average No. of questions per instance:    ]8;id=895669;file:///content/RocketEval-ICLR/src/rocketeval/process/judgment.py\judgment.py]8;;\:]8;id=263674;file:///content/RocketEval-ICLR/src/rocketeval/process/judgment.py#43\43]8;;\
#                     7.5375
#            INFO     Loaded 3200 results from 20 models                                               ]8;id=501712;file:///content/RocketEval-ICLR/src/rocketeval/process/judgment.py\judgment.py]8;;\:]8;id=337569;file:///content/RocketEval-ICLR/src/rocketeval/process/judgment.py#47\47]8;;\
# 100%|██████████| 20/20 [00:01<00:00, 11.34it/s]
# [06:24:57] INFO     Batch file output to                                                             ]8;id=725644;file:///content/RocketEval-ICLR/src/rocketeval/process/judgment.py\judgment.py]8;;\:]8;id=920512;file:///content/RocketEval-ICLR/src/rocketeval/process/judgment.py#86\86]8;;\
#                     "data/batch/mt-bench_Qwen2.5-0.5B-Instruct_1739946294_judgment.batch_submission.
#                     jsonl"
# [06:24:58] INFO     Total samples: 24120                                                              ]8;id=760794;file:///content/RocketEval-ICLR/src/rocketeval/tools/offline.py\offline.py]8;;\:]8;id=178276;file:///content/RocketEval-ICLR/src/rocketeval/tools/offline.py#97\97]8;;\
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# WARNING 02-19 06:25:11 config.py:2386] Casting torch.bfloat16 to torch.float16.
# INFO 02-19 06:25:25 config.py:542] This model supports multiple tasks: {'classify', 'reward', 'embed', 'score', 'generate'}. Defaulting to 'generate'.
# INFO 02-19 06:25:25 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.2) with config: model='Qwen/Qwen2.5-0.5B-Instruct', speculative_config=None, tokenizer='Qwen/Qwen2.5-0.5B-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.float16, max_seq_len=2400, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=Qwen/Qwen2.5-0.5B-Instruct, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":512}, use_cached_outputs=False,
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# INFO 02-19 06:25:30 cuda.py:179] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 02-19 06:25:30 cuda.py:227] Using XFormers backend.
# INFO 02-19 06:25:31 model_runner.py:1110] Starting to load model Qwen/Qwen2.5-0.5B-Instruct...
# INFO 02-19 06:25:31 weight_utils.py:252] Using model weights format ['*.safetensors']
# model.safetensors:   0%|          | 0.00/988M [00:00<?, ?B/s]
# INFO 02-19 06:25:55 weight_utils.py:297] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 02-19 06:25:57 model_runner.py:1115] Loading model weights took 0.9277 GB
# INFO 02-19 06:25:58 worker.py:267] Memory profiling takes 1.30 seconds
# INFO 02-19 06:25:58 worker.py:267] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.90) = 13.27GiB
# INFO 02-19 06:25:58 worker.py:267] model weights take 0.93GiB; non_torch_memory takes 0.05GiB; PyTorch activation peak memory takes 2.77GiB; the rest of the memory reserved for KV Cache is 9.53GiB.
# INFO 02-19 06:25:59 executor_base.py:110] # CUDA blocks: 52027, # CPU blocks: 21845
# INFO 02-19 06:25:59 executor_base.py:115] Maximum concurrency for 2400 tokens per request: 346.85x
# INFO 02-19 06:26:05 model_runner.py:1434] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes: 100%|██████████| 67/67 [01:04<00:00,  1.04it/s]
# INFO 02-19 06:27:09 model_runner.py:1562] Graph capturing finished in 64 secs, took 0.23 GiB
# INFO 02-19 06:27:09 llm_engine.py:431] init engine (profile, create kv cache, warmup model) took 72.42 seconds
# INFO 02-19 06:27:12 chat_utils.py:332] Detected the chat template content format to be 'string'. You can set `--chat-template-content-format` to override this.
# Processed prompts: 100%|██████████| 24120/24120 [06:33<00:00, 61.22it/s, est. speed input: 51786.82 toks/s, output: 61.22 toks/s]
# 100%|██████████| 20/20 [00:00<00:00, 42.28it/s]
# [06:35:53] INFO     Judgment results output to "data/mt-bench/judgment/Qwen2.5-0.5B-Instruct"       ]8;id=603424;file:///content/RocketEval-ICLR/src/rocketeval/process/judgment.py\judgment.py]8;;\:]8;id=661377;file:///content/RocketEval-ICLR/src/rocketeval/process/judgment.py#127\127]8;;\
#            INFO     Judgment Creation completed.                                 ]8;id=850045;file://<ipython-input-4-049d212b5d3f>\<ipython-input-4-049d212b5d3f>]8;;\:]8;id=902473;file://<ipython-input-4-049d212b5d3f>#136\136]8;;\
#            INFO     III. Score Creation                                          ]8;id=49633;file://<ipython-input-4-049d212b5d3f>\<ipython-input-4-049d212b5d3f>]8;;\:]8;id=707213;file://<ipython-input-4-049d212b5d3f>#143\143]8;;\
#   0%|          | 0/10 [00:00<?, ?it/s]
# [06:35:55] INFO     Score of "gpt-4o-mini" output to                                                   ]8;id=179359;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py\score.py]8;;\:]8;id=387584;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py#137\137]8;;\
#                     "data/mt-bench/score/Qwen2.5-0.5B-Instruct/gpt-4o-mini.json"
#            INFO     Score of "yi-large-preview" output to                                              ]8;id=257980;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py\score.py]8;;\:]8;id=238779;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py#137\137]8;;\
#                     "data/mt-bench/score/Qwen2.5-0.5B-Instruct/yi-large-preview.json"
#            INFO     Score of "Meta-Llama3-70B-Instruct" output to                                      ]8;id=204965;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py\score.py]8;;\:]8;id=799375;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py#137\137]8;;\
#                     "data/mt-bench/score/Qwen2.5-0.5B-Instruct/Meta-Llama3-70B-Instruct.json"
#            INFO     Score of "gpt-4" output to "data/mt-bench/score/Qwen2.5-0.5B-Instruct/gpt-4.json"  ]8;id=660511;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py\score.py]8;;\:]8;id=429016;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py#137\137]8;;\
#            INFO     Score of "Yi-1.5-34B-Chat" output to                                               ]8;id=861412;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py\score.py]8;;\:]8;id=938850;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py#137\137]8;;\
#                     "data/mt-bench/score/Qwen2.5-0.5B-Instruct/Yi-1.5-34B-Chat.json"
#            INFO     Score of "Meta-Llama-3-8B-Instruct" output to                                      ]8;id=439331;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py\score.py]8;;\:]8;id=771427;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py#137\137]8;;\
#                     "data/mt-bench/score/Qwen2.5-0.5B-Instruct/Meta-Llama-3-8B-Instruct.json"
#            INFO     Score of "claude-v1" output to                                                     ]8;id=429959;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py\score.py]8;;\:]8;id=879542;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py#137\137]8;;\
#                     "data/mt-bench/score/Qwen2.5-0.5B-Instruct/claude-v1.json"
#            INFO     Score of "claude-instant-v1" output to                                             ]8;id=849850;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py\score.py]8;;\:]8;id=880962;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py#137\137]8;;\
#                     "data/mt-bench/score/Qwen2.5-0.5B-Instruct/claude-instant-v1.json"
#            INFO     Score of "vicuna-33b-v1.3" output to                                               ]8;id=638501;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py\score.py]8;;\:]8;id=564381;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py#137\137]8;;\
#                     "data/mt-bench/score/Qwen2.5-0.5B-Instruct/vicuna-33b-v1.3.json"
#            INFO     Score of "vicuna-13b-v1.2" output to                                               ]8;id=471920;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py\score.py]8;;\:]8;id=288338;file:///content/RocketEval-ICLR/src/rocketeval/process/score.py#137\137]8;;\
#                     "data/mt-bench/score/Qwen2.5-0.5B-Instruct/vicuna-13b-v1.2.json"
# 100%|██████████| 10/10 [00:00<00:00, 202.24it/s]
#            INFO     Score Creation completed.                                    ]8;id=726514;file://<ipython-input-4-049d212b5d3f>\<ipython-input-4-049d212b5d3f>]8;;\:]8;id=638070;file://<ipython-input-4-049d212b5d3f>#155\155]8;;\
#            INFO     IV. Ranking                                                  ]8;id=464898;file://<ipython-input-4-049d212b5d3f>\<ipython-input-4-049d212b5d3f>]8;;\:]8;id=664904;file://<ipython-input-4-049d212b5d3f>#162\162]8;;\
#            INFO     Ranking output to "data/ranking/.tsv"                                                ]8;id=281546;file:///content/RocketEval-ICLR/src/rocketeval/process/rank.py\rank.py]8;;\:]8;id=9285;file:///content/RocketEval-ICLR/src/rocketeval/process/rank.py#38\38]8;;\
#
#
#                               Rank   model_test                 Qwen2.5-0.5B-Instruct
#                              ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                                  1   gpt-4o-mini                              6.57089
#                                  2   yi-large-preview                         6.26348
#                                  3   Yi-1.5-34B-Chat                          6.24259
#                                  4   Meta-Llama3-70B-Instruct                 6.23701
#                                  5   gpt-4                                    6.17788
#                                  6   Meta-Llama-3-8B-Instruct                 5.91072
#                                  7   vicuna-33b-v1.3                          5.87385
#                                  8   claude-instant-v1                        5.79136
#                                  9   claude-v1                                 5.7278
#                                 10   vicuna-13b-v1.2                          5.40156
#            INFO     Ranking completed.                                           ]8;id=734702;file://<ipython-input-4-049d212b5d3f>\<ipython-input-4-049d212b5d3f>]8;;\:]8;id=935911;file://<ipython-input-4-049d212b5d3f>#174\174]8;;\
#            INFO     RocketEval Completed                                         ]8;id=425564;file://<ipython-input-4-049d212b5d3f>\<ipython-input-4-049d212b5d3f>]8;;\:]8;id=635270;file://<ipython-input-4-049d212b5d3f>#181\181]8;;\

# %% [markdown]
# ------
#
# After deriving the scores and rankings, you can also export the data to the [LMSYS Chatbot Arena](https://lmarena.ai/) format for further analysis using the official [notebook](https://colab.research.google.com/drive/1KdwokPjirkTmpO_P1WByFNFiqxWQquwH).

# %%
from rocketeval.tools.export import chatbot_arena_match
from rocketeval.data.data_loader import load_target_models

load_target_models(dataset_name="mt-bench", split="test")
result = chatbot_arena_match(dataset_name="mt-bench", judge="Qwen2.5-0.5B-Instruct", model_names=test_model_names)
result.to_json("matches.jsonl", orient="records", lines=True)

result.head(5)
# Out:
#            model_a                   model_b   winner                  judge  \
# 0      gpt-4o-mini          yi-large-preview  model_b  Qwen2.5-0.5B-Instruct
# 1      gpt-4o-mini  Meta-Llama3-70B-Instruct      tie  Qwen2.5-0.5B-Instruct
# 2            gpt-4               gpt-4o-mini  model_b  Qwen2.5-0.5B-Instruct
# 3  Yi-1.5-34B-Chat               gpt-4o-mini  model_a  Qwen2.5-0.5B-Instruct
# 4      gpt-4o-mini  Meta-Llama-3-8B-Instruct  model_b  Qwen2.5-0.5B-Instruct
#
#    turn  anony language  tstamp  \
# 0     1   True  English  580830
# 1     1   True  English  580238
# 2     1   True  English  525352
# 3     1   True  English  250561
# 4     1   True  English   61569
#
#                                        conv_metadata  is_code  is_refusal  \
# 0  {'sum_user_tokens': 8, 'sum_assistant_a_tokens...    False       False
# 1  {'sum_user_tokens': 8, 'sum_assistant_a_tokens...    False       False
# 2  {'sum_user_tokens': 8, 'sum_assistant_a_tokens...    False       False
# 3  {'sum_user_tokens': 8, 'sum_assistant_a_tokens...    False       False
# 4  {'sum_user_tokens': 8, 'sum_assistant_a_tokens...    False       False
#
#                                dedup_tag  \
# 0  {'high_freq': False, 'sampled': True}
# 1  {'high_freq': False, 'sampled': True}
# 2  {'high_freq': False, 'sampled': True}
# 3  {'high_freq': False, 'sampled': True}
# 4  {'high_freq': False, 'sampled': True}
#
#                                         category_tag
# 0  {'if_v0.1': {'if': True, 'score': 4}, 'math_v0...
# 1  {'if_v0.1': {'if': True, 'score': 4}, 'math_v0...
# 2  {'if_v0.1': {'if': True, 'score': 4}, 'math_v0...
# 3  {'if_v0.1': {'if': True, 'score': 4}, 'math_v0...
# 4  {'if_v0.1': {'if': True, 'score': 4}, 'math_v0...

# %% [markdown]
# You can try on more powerful judge models and increase the number of test models to get a better and comprehensive evaluation result.
#
# ------
#
# If you find this work useful in your research, please consider citing the following paper:
# ```bibtex
# @inproceedings{wei2025rocketeval,
#     title={RocketEval: Efficient automated {LLM} evaluation via grading checklist},
#     author={Tianjun Wei and Wei Wen and Ruizhi Qiao and Xing Sun and Jianghong Ma},
#     booktitle={The Thirteenth International Conference on Learning Representations},
#     year={2025},
#     url={https://openreview.net/forum?id=zJjzNj6QUe}
# }
# ```
